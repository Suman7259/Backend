# %% [markdown]
# <a href="https://colab.research.google.com/github/Suman7259/Backend/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class LinearR:
    def __init__(self):
        self.m = None
        self.b = None

    def fit(self, X_train, Y_train):
        X_mean = X_train.mean()
        Y_mean = Y_train.mean()

        num = 0
        den = 0
        for i in range(X_train.shape[0]):
            num += (X_train[i] - X_mean) * (Y_train[i] - Y_mean)
            den += (X_train[i] - X_mean) ** 2

        self.m = num / den
        self.b = Y_mean - self.m * X_mean

        print("Slope (m):", self.m)
        print("Intercept (b):", self.b)

    def predict(self, X_test):
        return self.m * X_test + self.b

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/placement (1).csv')

# %%
X=df.iloc[:,0].values
Y=df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train,x_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
lr=LinearR()

# %%
lr.fit(X_train,Y_train)
# Out:
# Slope (m): 0.5579519734250721
# Intercept (b): -0.8961119222429152

# %%
lr.predict(x_test[0])
# Out:
# np.float64(3.891116009744203)
